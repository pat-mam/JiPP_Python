# %% [markdown]
# <a href="https://colab.research.google.com/github/pat-mam/JiPP_Python/blob/main/Zadanie2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input('Podaj Imie : ')
age = int(input('Podaj Wiek : '))
city = input('Podaj Miasto : ')
hobby = input('Podaj Hobby : ')
string = "Hi {name}, you are {age} years old. You live in {city} and you love {hobby}!"

output = string.format(name=name,age=age,city=city,hobby=hobby)
print(output)
# Out:
# Podaj Imie : Adam
# Podaj Wiek : 12
# Podaj Miasto : Wawa
# Podaj Hobby : Muza
# Hi Adam, you are 12 years old. You live in Wawa and you love Muza!
