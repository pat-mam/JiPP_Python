# %% [markdown]
# <a href="https://colab.research.google.com/github/pat-mam/JiPP_Python/blob/main/Ciekawskie_Dziecko.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

questions = ["Why is the sky blue?\n","Why is the sun round?\n","Where are all the dinosaurs?\n"]


pyt = random.choice(questions)

answer = input(pyt).strip().lower()

while answer != "to wszystko!":
    answer = input("Dlaczego?\n")


print("No dobra!")
