# %% [markdown]
# <a href="https://colab.research.google.com/github/pat-mam/JiPP_Python/blob/main/Zad1_Operacje_na_plikach_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
filename="story.txt"
i=0

with open(filename) as file_object:
    for line in file_object:
        words = line.split()
        i += len(words)

print("Słów jest: ", i)
# Out:
# Słów jest:  42
