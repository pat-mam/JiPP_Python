# %% [markdown]
# <a href="https://colab.research.google.com/github/pat-mam/JiPP_Python/blob/main/kalkulator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add(a, b):
   return a + b

def Subtract(a, b):
   return a - b

def Multiply(a, b):
   return a * b

def Divide(a, b):
   return a / b


while True:

    print("-------------------------------\nPlease select the operation.")
    print("a. Add")
    print("b. Subtract")
    print("c. Multiply")
    print("d. Divide")
    print("e. Exit")

    op = input("Please enter choice (a/ b/ c/ d/ e): ")


    if op == 'e':
        print("Goodbye!")
        break


    if op in ['a', 'b', 'c', 'd']:
        try:
            a = int(input("Please enter the first number: "))
            b = int(input("Please enter the second number: "))
        except ValueError:
            print("Error: Please enter valid numbers only!")
            continue

        if op == 'a':
            print(f"Result: {add(a, b)}")
        elif op == 'b':
            print(f"Result: {Subtract(a, b)}")
        elif op == 'c':
            print(f"Result: {Multiply(a, b)}")
        elif op == 'd':
            if b == 0:
                print("Error: Cannot divide by zero")
            else:
                print(f"Result: {Divide(a, b)}")


    else:
        print("Invalid input! Please choose a, b, c, d or e.")
# Out:
# -------------------------------
# Please select the operation.
# a. Add
# b. Subtract
# c. Multiply
# d. Divide
# e. Exit
# Please enter choice (a/ b/ c/ d/ e): a
# Please enter the first number: 1
# Please enter the second number: 1
# Result: 2
# -------------------------------
# Please select the operation.
# a. Add
# b. Subtract
# c. Multiply
# d. Divide
# e. Exit
# Please enter choice (a/ b/ c/ d/ e): e
# Goodbye!
