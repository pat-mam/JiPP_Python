# %% [markdown]
# <a href="https://colab.research.google.com/github/pat-mam/JiPP_Python/blob/main/Zad3_Operacje_na_plikach_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

filename="numbers.txt"
sum=0

with open(filename,'r') as f:

  for line in f:
    sum+=int(line)

print(sum)
# Out:
# 1161
