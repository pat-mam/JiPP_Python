# %% [markdown]
# <a href="https://colab.research.google.com/github/pat-mam/JiPP_Python/blob/main/Zad2_Operacje_na_plikach_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

filename="fruits.txt"

wards=["Apple","Banana","Cherry"]

with open(filename, "w") as f:
  for words in wards:
    f.write(words + "\n")
