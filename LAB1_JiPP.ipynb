# %%
import sys
print(sys.version)
# Out:
# 3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]

# %% [markdown]
# #Deklaracja Zmiennych

# %%
num = 10
num
# Out:
# 10

# %%
type(num)
# Out:
# int

# %%
num='Ten'
num
# Out:
# 'Ten'

# %%
type(num)
# Out:
# str

# %%
print(num)
type(num)
# Out:
# Ten
# str

# %% [markdown]
# Cwiczenie: Python zmienne

# %%
x=10
y=55
z=x+y
x=z
print(z)
# Out:
# 65
