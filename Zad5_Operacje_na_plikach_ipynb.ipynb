# %% [markdown]
# <a href="https://colab.research.google.com/github/pat-mam/JiPP_Python/blob/main/Zad5_Operacje_na_plikach_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

filename="user.txt"


with open(filename,"a") as f:
  name=input("Wpisz imie: ")
  age=input("Wpisz wiek: ")
  f.write("Imie: "+name+" Wiek: "+age+"\n")


with open(filename,"r") as f:
  print("\nZawartosc pliku:\n")
  print(f.read())
